# %% [markdown]
# # Bonus: Temperature Analysis I

# %%
import pandas as pd
from datetime import datetime as dt
import matplotlib

# %%
# "tobs" is "temperature observations"
df = pd.read_csv('Resources/hawaii_measurements.csv')
df.dtypes
# Out:
# station     object
# date        object
# prcp       float64
# tobs         int64
# dtype: object

# %%
# Convert the date column format from string to datetime


df['date'] = pd.to_datetime(df['date'], errors='coerce')
df.dtypes
# Out:
# station            object
# date       datetime64[ns]
# prcp              float64
# tobs                int64
# dtype: object

# %%
# Set the date column as the DataFrame index
#df = df.set_index('date')

df.set_index(df['date'], inplace=True)

# Sort the dataframe by date
# df = df.sort_values("date")
df = df.sort_index()

df
# Out:
#                 station       date  prcp  tobs
# date
# 2010-01-01  USC00519397 2010-01-01  0.08    65
# 2010-01-01  USC00518838 2010-01-01  0.21    72
# 2010-01-01  USC00519523 2010-01-01  0.15    75
# 2010-01-01  USC00519281 2010-01-01  0.15    70
# 2010-01-01  USC00511918 2010-01-01  0.05    66
# ...                 ...        ...   ...   ...
# 2017-08-22  USC00516128 2017-08-22  0.50    76
# 2017-08-23  USC00519397 2017-08-23  0.00    81
# 2017-08-23  USC00514830 2017-08-23  0.00    82
# 2017-08-23  USC00519523 2017-08-23  0.08    82
# 2017-08-23  USC00516128 2017-08-23  0.45    76
#
# [19550 rows x 4 columns]

# %%
# Drop the date column
clean_df = df.drop('date', axis=1)

clean_df
# Out:
#                 station  prcp  tobs
# date
# 2010-01-01  USC00519397  0.08    65
# 2010-01-01  USC00518838  0.21    72
# 2010-01-01  USC00519523  0.15    75
# 2010-01-01  USC00519281  0.15    70
# 2010-01-01  USC00511918  0.05    66
# ...                 ...   ...   ...
# 2017-08-22  USC00516128  0.50    76
# 2017-08-23  USC00519397  0.00    81
# 2017-08-23  USC00514830  0.00    82
# 2017-08-23  USC00519523  0.08    82
# 2017-08-23  USC00516128  0.45    76
#
# [19550 rows x 3 columns]

# %%
df['day'] = clean_df.index.day
df['month'] = clean_df.index.month
df['year'] = clean_df.index.year

clean_df = df.drop('date', axis=1)

clean_df

# june_mask = df['date'].map(lambda x: x.month) == 6 
# ju = clean_df[june_mask]
# june

# dec_mask = df['date'].map(lambda x: x.month) == 12 
# december = clean_df[dec_mask]
# Out:
#                 station  prcp  tobs  day  month  year
# date
# 2010-01-01  USC00519397  0.08    65    1      1  2010
# 2010-01-01  USC00518838  0.21    72    1      1  2010
# 2010-01-01  USC00519523  0.15    75    1      1  2010
# 2010-01-01  USC00519281  0.15    70    1      1  2010
# 2010-01-01  USC00511918  0.05    66    1      1  2010
# ...                 ...   ...   ...  ...    ...   ...
# 2017-08-22  USC00516128  0.50    76   22      8  2017
# 2017-08-23  USC00519397  0.00    81   23      8  2017
# 2017-08-23  USC00514830  0.00    82   23      8  2017
# 2017-08-23  USC00519523  0.08    82   23      8  2017
# 2017-08-23  USC00516128  0.45    76   23      8  2017
#
# [19550 rows x 6 columns]

# %% [markdown]
# ### Compare June and December data across all years

# %%
from scipy import stats

# %%
# Filter data for desired months
# dec_df = clean_df.loc['2010-12-01':'2014-12-31']
# dec_df
# june_df = clean_df.loc['2010-06-01':'2016-06-30'] 

# june_df

# june = clean_df.loc[clean_df['month'] == "6",]
# june

# %%
# Identify the average temperature for June

avg_june_temp = clean_df[clean_df["month"] == 6]
avg_june_temp['tobs'].mean()

# june = clean_df.loc[clean_df['month'] == 6]

# avg_june = june.groupby(['month']).mean()
# avg_temp_june = avg_june['tobs']
# avg_temp_june
# Out:
# 74.94411764705882

# %%
# Identify the average temperature for December

avg_dec_temp = clean_df[clean_df["month"] == 12]
avg_dec_temp['tobs'].mean()

avg_dec_temp = clean_df[clean_df["month"] == 12]
avg_dec_temp['tobs'].mean()
# december = clean_df.loc[clean_df['month'] == 12]


# avg_dec = december.groupby(['month']).mean()
# avg_dec_temp = avg_dec['tobs']
# Out:
# 71.04152933421226

# %%
# Create collections of temperature data

avg_dec_temp
# Out:
#                 station  prcp  tobs  day  month  year
# date
# 2010-12-01  USC00511918  0.13    70    1     12  2010
# 2010-12-01  USC00519397  0.04    76    1     12  2010
# 2010-12-01  USC00513117  0.76    73    1     12  2010
# 2010-12-01  USC00519281  1.35    72    1     12  2010
# 2010-12-01  USC00516128  1.48    71    1     12  2010
# ...                 ...   ...   ...  ...    ...   ...
# 2016-12-31  USC00516128  0.90    65   31     12  2016
# 2016-12-31  USC00514830  0.36    72   31     12  2016
# 2016-12-31  USC00519281  0.25    67   31     12  2016
# 2016-12-31  USC00519397  0.01    66   31     12  2016
# 2016-12-31  USC00513117  0.62    71   31     12  2016
#
# [1517 rows x 6 columns]

# %%
avg_june_temp
# Out:
#                 station  prcp  tobs  day  month  year
# date
# 2010-06-01  USC00511918  0.00    74    1      6  2010
# 2010-06-01  USC00519523  0.03    76    1      6  2010
# 2010-06-01  USC00514830  0.01    73    1      6  2010
# 2010-06-01  USC00519281  0.00    71    1      6  2010
# 2010-06-01  USC00516128  0.08    70    1      6  2010
# ...                 ...   ...   ...  ...    ...   ...
# 2017-06-30  USC00513117  0.04    74   30      6  2017
# 2017-06-30  USC00514830  0.00    81   30      6  2017
# 2017-06-30  USC00517948  0.12    74   30      6  2017
# 2017-06-30  USC00519523  0.07    75   30      6  2017
# 2017-06-30  USC00519281  0.01    76   30      6  2017
#
# [1700 rows x 6 columns]

# %%
# Run paired t-test 

stats.ttest_ind(avg_dec_temp.tobs, avg_june_temp.tobs, equal_var=False)
# Out:
# Ttest_indResult(statistic=-31.355036920962423, pvalue=4.193529835915755e-187)

# %% [markdown]
# ### Analysis
